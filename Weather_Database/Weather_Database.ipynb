# %% [markdown]
# # Deliverable 1

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

import os  ## needed to change dir to import keys from different folder
import requests  ## needed for web crawls 
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
from datetime import datetime
import time

# %%
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Save combinations to a list.
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(-75.97766169164248, -15.664356657087353), (2.1265771760571113, -98.20107196582978), (-0.16421972738297086, 121.15036142230599), (-64.2707411574914, -64.50200953410773), (1.354448728805366, -110.81467145128532), (66.47175864433751, -173.49002621884844), (34.265635551835175, -46.97771376610595), (69.88494827976118, -132.42817608165012), (40.271456508104194, -134.44782052935153), (-15.75044825281573, 172.23940334299544), (-88.8932315531077, -139.28102550999563), (85.67111473698105, -79.3502489265178), (76.48212223333744, 18.366135648102812), (-1.8880855654709308, -99.05841623221457), (-63.73246214601771, 104.49952418128703), (31.568392639907188, -21.44946786424933), (-29.010808506679666, -110.17225819258921), (-21.25471239826929, 7.401729292555672), (55.742881959868754, 36.02337483425151), (-52.32743872497185, -151.93649467896782), (-28.4028962994717, -103.53541076575087), (9.237847789188777, 138.12830661845982), (-16.64346026198126, -79.38159432953805), (-0.8700146123535291, 34.42102067298225), (-49.15126428772944, 130.50029004920526), (-8.914424344329376, 51.608885282188965), (30.37529424113805, 135.23272000070182), (-63.39620513310692, -132.26940685852017), (18.19672359939794, 158.59843927536008), (-19.819650872419217, -141.69553280707618), (69.22594723763842, 106.38375598576437), (15.73814571485319, -105.67395707869318), (-44.585404221079145, 32.573597543867976), (17.820427497581804, -5.943819602156907), (-4.668819201519085, 109.71372563569093), (28.65648036698235, -133.41616083647818), (-6.490766191891609, -128.71535378566188), (-59.26402862935431, -9.79837160726612), (-16.434361205176472, 0.8482878341044398), (81.8941325860977, -150.86548296658006), (-57.84076298729389, 135.94930510536886), (60.096273739113, -34.622466636094174), (80.58379622908649, -46.66584299683666), (-76.60485847825322, 172.33703853553664), (81.06689562479633, -129.49339618675276), (82.24923039332256, -105.45152607174279), (71.00291125217967, -172.91640076802724), (19.276452823808356, -103.0797280506291), (31.97149530864867, -176.59980432593935), (28.15927598739802, -123.16938812749997), (21.933478861162882, 126.30310103409914), (-19.901859278324707, -46.43084754603234), (-76.49669584822641, -146.8211856889898), (-5.032449031647602, 94.11930317136802), (82.25075421705097, 109.17811656932003), (73.63093254458249, 178.05604516238566), (-70.06996584924545, -96.940894748385), (-81.21132542778118, 147.7681473381461), (-45.62731592764445, 174.28540640445874), (64.14776101651174, -149.91187061456608), (-36.78418547847823, -63.354618256478105), (-29.376677181054916, -153.41468772761826), (33.90657398172593, -178.00317124985247), (65.78147257810099, -157.47217955195936), (70.21507505672173, -43.65623902625251), (-11.032169110511049, 61.4831775180468), (69.22120131784928, -108.697551094476), (-56.405171706752895, -15.33641144439602), (-2.7286436343906644, -142.23451347090602), (-5.6330869724644685, -144.5836562984175), (73.25000768591642, -18.42327829717692), (-7.328519180007277, 63.08626079259895), (-1.420384928028085, -156.64203131650325), (13.568046452521514, -75.34777603571865), (38.51868417834325, 10.709037237392266), (-77.59246183843808, 90.31717955721888), (-8.93377467357901, 28.17021220792128), (-59.54356386644507, -143.8810246415578), (-47.59919947632332, 32.104972283876094), (-9.677849194059405, -16.410132403897563), (60.09318673363305, 125.20498274165249), (48.645888258171965, 52.69516688591753), (16.844199083235267, -87.92906431980195), (8.791217911557794, 65.71456921711794), (88.30637448169566, 78.00081320848977), (49.96629746592376, -111.04342436393148), (-84.7250770929515, -34.774619836996095), (86.21754283825805, -98.3985611850084), (73.51075493030456, 63.72921759212943), (-39.78108486695916, -165.2138126665614), (-13.881803726128055, 160.8386145454479), (-9.971033060079108, 50.91298617619563), (-58.96156318872213, -88.02564427225671), (42.49316627846409, -6.49710044942816), (9.379122798002683, -18.206783285257274), (-70.72476239292119, 43.43300 ...

# %%
# Use the print() function to display the latitude and longitude combinations.
# Create list to hold cities
cities = []

# identify nearest city for coordinate combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Remember to avoid duplicates:
    if city not in cities:
        cities.append(city)
        
# Print length of city list:
len(cities)
# Out:
# 731

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50): 
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": description })
    

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | poso
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | lazaro cardenas
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | vila
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | henties bay
# Processing Record 17 of Set 2 | ruza
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | airai
# Processing Record 20 of Set 2 | pisco
# Processing Record 21 of Set 2 | migori
# Processing Record 22 of Set 2 | mount gambier
# Processing Record 23 of Set 2 | ambilobe
# Processing Record 24 of Set 2 | muroto
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | manzanillo
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | araouane
# Processing Record 30 of Set 2 | mlonggo
# Processing Record 31 of Set 2 | pacific grove
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | ilulissat
# Processing Record 38 of Set 2 | bluff
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | lavrentiya
# Processing Record 41 of Set 2 | tepalcatepec
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | lompoc
# Processing Record 44 of Set 2 | hirara
# Processing Record 45 of Set 2 | campos altos
# Processing Record 46 of Set 2 | padang
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | leningradskiy
# Processing Record 49 of Set 2 | punta arenas
# Processing Record 50 of Set 2 | hobart
# Processing Record 1 of Set 3 | christchurch
# Processing Record 2 of Set 3 | college
# Processing Record 3 of Set 3 | santa rosa
# Processing Record 4 of Set 3 | victoria
# Processing Record 5 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | santa marta
# Processing Record 8 of Set 3 | rafraf
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | nchelenge
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | nizhniy kuranakh
# Processing Record 13 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | dangriga
# Processing Record 15 of Set 3 | kavaratti
# Processing Record 16 of Set 3 | dikson
# Processing Record 17 of Set 3 | bow island
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | kirakira
# Processing Record 21 of Set 3 | ponferrada
# Processing Record 22 of Set 3 | bubaque
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | hithadhoo
# Processing Record 26 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 3 | faya
# Processing Record 28 of Set 3 | wamba
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | ambulu
# Processing Record 31 of Set 3 | vaini
# Processing Record 32 of Set 3 | sokode
# Processing Record 33 of Set 3 | lorengau
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | castro
# Processing Record 36 of Set 3 | carnarvon
# Processing Record 37 of Set 3 | hermanus
# Processing Record 38 of Set 3 | igarka
# Processing Record 39 of Set 3 | tukrah
# Processing Record 40 of Set 3 | paamiut
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | coihaique
# Processing Record 43 of Set 3 | babra
# Processing Record 44 of Set 3 | bhadasar
# Processing Record 45 of Set 3 | halifax
# Processing Record 46 of Set 3 | thompson
# Processing Record 47 of Set 3 | kruisfontein
# Processing Record 48 of Set 3 | khandyga
# Processing Record 49 of Set 3 | hualmay
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 2 of Set 4 | chhuikhadan
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | taoudenni
# Processing Record 5 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 4 | mandalay
# Processing Record 7 of Set 4 | clyde river
# Processing Record 8 of Set 4 | karratha
# Processing Record 9 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 4 | haines junction
# Processing Record 11 of Set 4 | port elizabeth
# Processing Record 12 of Set 4 | chokurdakh
# Processing Record 13 of Set 4 | murindo
# Processing Record 14 of Set 4 | luderitz
# Processing Record 15 of Set 4 | tecoanapa
# Processing Record 16 of Set 4 | pevek
# Processing Record 17 of Set 4 | seoul
# Processing Record 18 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 4 | morehead
# Processing Record 20 of Set 4 | ust-kuyga
# Processing Record 21 of Set 4 | arraial do cabo
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | salisbury
# Processing Record 24 of Set 4 | guerrero negro
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 4 | walvis bay
# Processing Record 28 of Set 4 | kisangani
# Processing Record 29 of Set 4 | poum
# Processing Record 30 of Set 4 | novo aripuana
# Processing Record 31 of Set 4 | thinadhoo
# Processing Record 32 of Set 4 | puerto escondido
# Processing Record 33 of Set 4 | bozeman
# Processing Record 34 of Set 4 | fairbanks
# Processing Record 35 of Set 4 | severo-kurilsk
# Processing Record 36 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 4 | carutapera
# Processing Record 39 of Set 4 | iqaluit
# Processing Record 40 of Set 4 | saint george
# Processing Record 41 of Set 4 | beringovskiy
# Processing Record 42 of Set 4 | hami
# Processing Record 43 of Set 4 | upernavik
# Processing Record 44 of Set 4 | luganville
# Processing Record 45 of Set 4 | san antonio
# Processing Record 46 of Set 4 | saint cloud
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | brae
# Processing Record 49 of Set 4 | tchibanga
# Processing Record 50 of Set 4 | port lincoln
# Processing Record 1 of Set 5 | rawson
# Processing Record 2 of Set 5 | choya
# Processing Record 3 of Set 5 | pangai
# Processing Record 4 of Set 5 | boca do acre
# Processing Record 5 of Set 5 | zeya
# Processing Record 6 of Set 5 | ishigaki
# Processing Record 7 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | fort nelson
# Processing Record 10 of Set 5 | san quintin
# Processing Record 11 of Set 5 | salvador
# Processing Record 12 of Set 5 | bowen
# Processing Record 13 of Set 5 | progreso
# Processing Record 14 of Set 5 | nanortalik
# Processing Record 15 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 5 | bredasdorp
# Processing Record 17 of Set 5 | biltine
# Processing Record 18 of Set 5 | salalah
# Processing Record 19 of Set 5 | deputatskiy
# Processing Record 20 of Set 5 | paris
# Processing Record 21 of Set 5 | chuy
# Processing Record 22 of Set 5 | qui nhon
# Processing Record 23 of Set 5 | lagoa
# Processing Record 24 of Set 5 | denpasar
# Processing Record 25 of Set 5 | pangnirtung
# Processing Record 26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 5 | amahai
# Processing Record 28 of Set 5 | bambous virieux
# Processing Record 29 of Set 5 | mount isa
# Processing Record 30 of Set 5 | bilibino
# Processing Record 31 of Set 5 | palmer
# Processing Record 32 of Set 5 | cockburn town
# Processing Record 33 of Set 5 | bardiyah
# Processing Record 34 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 5 | maloy
# Processing Record 36 of Set 5 | klaksvik
# Processing Record 37 of Set 5 | ribeira grande
# Processing Record 38 of Set 5 | penzance
# Processing Record 39 of Set 5 | sao joao da ponte
# Processing Record 40 of Set 5 | basco
# Processing Record 41 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 42 of Set 5 | husavik
# Processing Record 43 of Set 5 | bykovo
# Processing Record 44 of Set 5 | panama city
# Processing Record 45 of Set 5 | roma
# Processing Record 46 of Set 5 | maumere
# Processing Record 47 of Set 5 | abu samrah
# Processing Record 48 of Set 5 | westport
# Processing Record 49 of Set 5 | raahe
# Processing Record 50 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 6 | baruun-urt
# Processing Record 2 of Set 6 | maxixe
# Processing Record 3 of Set 6 | micheweni
# Processing Record 4 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 6 | mongo
# Processing Record 6 of Set 6 | iwanai
# Processing Record 7 of Set 6 | callaguip
# Processing Record 8 of Set 6 | dalinghe
# City not found. Skipping...
# Processing Record 9 of Set 6 | osakarovka
# Processing Record 10 of Set 6 | callaway
# Processing Record 11 of Set 6 | dakar
# Processing Record 12 of Set 6 | lapeer
# Processing Record 13 of Set 6 | huejuquilla el alto
# Processing Record 14 of Set 6 | ponta delgada
# Processing Record 15 of Set 6 | narsaq
# Processing Record 16 of Set 6 | harper
# Processing Record 17 of Set 6 | matagami
# Processing Record 18 of Set 6 | banda aceh
# Processing Record 19 of Set 6 | lebu
# Processing Record 20 of Set 6 | sinegorye
# Processing Record 21 of Set 6 | vanimo
# Processing Record 22 of Set 6 | sao gabriel da cachoeira
# Processing Record 23 of Set 6 | daru
# Processing Record 24 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 6 | san cristobal
# Processing Record 26 of Set 6 | coffs harbour
# Processing Record 27 of Set 6 | dingle
# Processing Record 28 of Set 6 | whittlesea
# Processing Record 29 of Set 6 | souillac
# Processing Record 30 of Set 6 | bethel
# Processing Record 31 of Set 6 | chimore
# Processing Record 32 of Set 6 | herouville-saint-clair
# Processing Record 33 of Set 6 | izumo
# Processing Record 34 of Set 6 | badou
# Processing Record 35 of Set 6 | srednekolymsk
# Processing Record 36 of Set 6 | ayagoz
# Processing Record 37 of Set 6 | sandanski
# Processing Record 38 of Set 6 | linxia
# Processing Record 39 of Set 6 | colares
# Processing Record 40 of Set 6 | quatre cocos
# Processing Record 41 of Set 6 | la ronge
# Processing Record 42 of Set 6 | balakhta
# Processing Record 43 of Set 6 | agadir
# Processing Record 44 of Set 6 | tsumeb
# Processing Record 45 of Set 6 | sorland
# Processing Record 46 of Set 6 | hasaki
# Processing Record 47 of Set 6 | phu ly
# Processing Record 48 of Set 6 | hambantota
# Processing Record 49 of Set 6 | aguas vermelhas
# Processing Record 50 of Set 6 | ancud
# Processing Record 1 of Set 7 | mar del plata
# Processing Record 2 of Set 7 | flinders
# Processing Record 3 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 4 of Set 7 | mahanoro
# Processing Record 5 of Set 7 | ankang
# Processing Record 6 of Set 7 | traverse city
# Processing Record 7 of Set 7 | trinidad
# Processing Record 8 of Set 7 | east london
# Processing Record 9 of Set 7 | cherskiy
# Processing Record 10 of Set 7 | mahibadhoo
# Processing Record 11 of Set 7 | axim
# Processing Record 12 of Set 7 | ambon
# Processing Record 13 of Set 7 | nea stira
# Processing Record 14 of Set 7 | praia da vitoria
# Processing Record 15 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 7 | shakawe
# Processing Record 17 of Set 7 | orange cove
# Processing Record 18 of Set 7 | butembo
# Processing Record 19 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 7 | constitucion
# Processing Record 21 of Set 7 | miguel auza
# Processing Record 22 of Set 7 | cayenne
# Processing Record 23 of Set 7 | portland
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 7 | samarinda
# Processing Record 27 of Set 7 | codrington
# Processing Record 28 of Set 7 | tocopilla
# Processing Record 29 of Set 7 | mamontovo
# Processing Record 30 of Set 7 | sabang
# Processing Record 31 of Set 7 | mulege
# Processing Record 32 of Set 7 | palauig
# Processing Record 33 of Set 7 | haimen
# Processing Record 34 of Set 7 | ipixuna
# Processing Record 35 of Set 7 | constantine
# Processing Record 36 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 7 | akdepe
# Processing Record 38 of Set 7 | mamallapuram
# Processing Record 39 of Set 7 | veraval
# Processing Record 40 of Set 7 | kuopio
# Processing Record 41 of Set 7 | akyab
# Processing Record 42 of Set 7 | whitley bay
# Processing Record 43 of Set 7 | inhambane
# Processing Record 44 of Set 7 | khomeynishahr
# City not found. Skipping...
# Processing Record 45 of Set 7 | margate
# Processing Record 46 of Set 7 | davenport
# Processing Record 47 of Set 7 | lahij
# Processing Record 48 of Set 7 | te anau
# Processing Record 49 of Set 7 | comodoro rivadavia
# Processing Record 50 of Set 7 | keelung
# Processing Record 1 of Set 8 | zagare
# Processing Record 2 of Set 8 | cidreira
# Processing Record 3 of Set 8 | sambava
# Processing Record 4 of Set 8 | qaqortoq
# Processing Record 5 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 8 | tuim
# Processing Record 7 of Set 8 | vestmanna
# Processing Record 8 of Set 8 | sonoita
# Processing Record 9 of Set 8 | payo
# Processing Record 10 of Set 8 | bulawayo
# Processing Record 11 of Set 8 | takanabe
# Processing Record 12 of Set 8 | qiqihar
# Processing Record 13 of Set 8 | san patricio
# Processing Record 14 of Set 8 | inirida
# Processing Record 15 of Set 8 | parana
# Processing Record 16 of Set 8 | varia
# Processing Record 17 of Set 8 | yanji
# Processing Record 18 of Set 8 | rorvik
# Processing Record 19 of Set 8 | gat
# Processing Record 20 of Set 8 | kearney
# Processing Record 21 of Set 8 | vardo
# Processing Record 22 of Set 8 | muisne
# Processing Record 23 of Set 8 | rottingdean
# Processing Record 24 of Set 8 | avera
# Processing Record 25 of Set 8 | gizo
# Processing Record 26 of Set 8 | kibala
# Processing Record 27 of Set 8 | mizan teferi
# Processing Record 28 of Set 8 | havoysund
# Processing Record 29 of Set 8 | omsukchan
# Processing Record 30 of Set 8 | saint-philippe
# Processing Record 31 of Set 8 | cortez
# Processing Record 32 of Set 8 | terney
# Processing Record 33 of Set 8 | panjab
# Processing Record 34 of Set 8 | kloulklubed
# Processing Record 35 of Set 8 | mangrol
# Processing Record 36 of Set 8 | marsh harbour
# Processing Record 37 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 38 of Set 8 | namatanai
# Processing Record 39 of Set 8 | pilar
# Processing Record 40 of Set 8 | hamilton
# Processing Record 41 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 8 | loa janan
# Processing Record 43 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 8 | makaha
# Processing Record 45 of Set 8 | minot
# Processing Record 46 of Set 8 | monte patria
# Processing Record 47 of Set 8 | cap malheureux
# Processing Record 48 of Set 8 | aklavik
# Processing Record 49 of Set 8 | asyut
# Processing Record 50 of Set 8 | sinop
# Processing Record 1 of Set 9 | bolshoy uluy
# City not found. Skipping...
# Processing Record 2 of Set 9 | mareeba
# Processing Record 3 of Set 9 | pierre
# Processing Record 4 of Set 9 | santa isabel do rio negro
# Processing Record 5 of Set 9 | caravelas
# Processing Record 6 of Set 9 | podor
# Processing Record 7 of Set 9 | kahului
# Processing Record 8 of Set 9 | goure
# Processing Record 9 of Set 9 | talnakh
# Processing Record 10 of Set 9 | krasnoselkup
# Processing Record 11 of Set 9 | alugan
# Processing Record 12 of Set 9 | concarneau
# Processing Record 13 of Set 9 | touros
# Processing Record 14 of Set 9 | sao joao da barra
# Processing Record 15 of Set 9 | sabha
# Processing Record 16 of Set 9 | vernon
# Processing Record 17 of Set 9 | kihei
# Processing Record 18 of Set 9 | puerto leguizamo
# Processing Record 19 of Set 9 | hoopstad
# Processing Record 20 of Set 9 | birjand
# Processing Record 21 of Set 9 | cruzeiro do sul
# Processing Record 22 of Set 9 | tezu
# Processing Record 23 of Set 9 | korop
# Processing Record 24 of Set 9 | saint-georges
# Processing Record 25 of Set 9 | la reforma
# Processing Record 26 of Set 9 | yenagoa
# Processing Record 27 of Set 9 | launceston
# Processing Record 28 of Set 9 | grand gaube
# Processing Record 29 of Set 9 | dunedin
# Processing Record 30 of Set 9 | los llanos de aridane
# Processing Record 31 of Set 9 | broome
# Processing Record 32 of Set 9 | yulara
# Processing Record 33 of Set 9 | rabat
# Processing Record 34 of Set 9 | changji
# Processing Record 35 of Set 9 | dustlik
# Processing Record 36 of Set 9 | arbazh
# Processing Record 37 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 38 of Set 9 | saint peter
# Processing Record 39 of Set 9 | deer lake
# Processing Record 40 of Set 9 | muleba
# Processing Record 41 of Set 9 | mustasaari
# Processing Record 42 of Set 9 | nampula
# Processing Record 43 of Set 9 | osoyoos
# Processing Record 44 of Set 9 | norman wells
# Processing Record 45 of Set 9 | nouadhibou
# Processing Record 46 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 9 | iskateley
# Processing Record 48 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 49 of Set 9 | bukachacha
# Processing Record 50 of Set 9 | marang
# Processing Record 1 of Set 10 | kingussie
# Processing Record 2 of Set 10 | avon
# Processing Record 3 of Set 10 | villarrica
# Processing Record 4 of Set 10 | petropavlovka
# Processing Record 5 of Set 10 | shatrovo
# Processing Record 6 of Set 10 | lockhart
# Processing Record 7 of Set 10 | borzya
# Processing Record 8 of Set 10 | la grande
# Processing Record 9 of Set 10 | paracuru
# Processing Record 10 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 11 of Set 10 | lichuan
# Processing Record 12 of Set 10 | vostok
# Processing Record 13 of Set 10 | pozo colorado
# Processing Record 14 of Set 10 | sao filipe
# Processing Record 15 of Set 10 | aragats
# Processing Record 16 of Set 10 | nouakchott
# Processing Record 17 of Set 10 | copiapo
# Processing Record 18 of Set 10 | bantry
# Processing Record 19 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 10 | olden
# Processing Record 21 of Set 10 | taksimo
# Processing Record 22 of Set 10 | plettenberg bay
# Processing Record 23 of Set 10 | tabas
# Processing Record 24 of Set 10 | sumbe
# Processing Record 25 of Set 10 | dzidzantun
# Processing Record 26 of Set 10 | itoman
# Processing Record 27 of Set 10 | darovskoy
# Processing Record 28 of Set 10 | asau
# Processing Record 29 of Set 10 | hofn
# Processing Record 30 of Set 10 | komsomolskiy
# Processing Record 31 of Set 10 | kamenka
# Processing Record 32 of Set 10 | ballstad
# City not found. Skipping...
# Processing Record 33 of Set 10 | mabaruma
# Processing Record 34 of Set 10 | ardakan
# Processing Record 35 of Set 10 | port moresby
# Processing Record 36 of Set 10 | rundu
# Processing Record 37 of Set 10 | kajaani
# Processing Record 38 of Set 10 | tuy hoa
# Processing Record 39 of Set 10 | aksarayskiy
# Processing Record 40 of Set 10 | udachnyy
# Processing Record 41 of Set 10 | pochutla
# Processing Record 42 of Set 10 | plymouth
# Processing Record 43 of Set 10 | nador
# Processing Record 44 of Set 10 | ruidoso
# Processing Record 45 of Set 10 | aviles
# Processing Record 46 of Set 10 | brokopondo
# Processing Record 47 of Set 10 | onega
# Processing Record 48 of Set 10 | kainantu
# Processing Record 49 of Set 10 | kita
# Processing Record 50 of Set 10 | sarajevo
# Processing Record 1 of Set 11 | kavieng
# Processing Record 2 of Set 11 | lodwar
# Processing Record 3 of Set 11 | hikari
# Processing Record 4 of Set 11 | kargasok
# Processing Record 5 of Set 11 | atasu
# Processing Record 6 of Set 11 | ninohe
# Processing Record 7 of Set 11 | viedma
# Processing Record 8 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 11 | hailar
# Processing Record 11 of Set 11 | port blair
# Processing Record 12 of Set 11 | jumla
# Processing Record 13 of Set 11 | nanakuli
# Processing Record 14 of Set 11 | hit
# Processing Record 15 of Set 11 | lumphat
# Processing Record 16 of Set 11 | maragogi
# Processing Record 17 of Set 11 | kidal
# Processing Record 18 of Set 11 | vila franca do campo
# Processing Record 19 of Set 11 | thunder bay
# Processing Record 20 of Set 11 | alofi
# Processing Record 21 of Set 11 | hendijan
# City not found. Skipping...
# Processing Record 22 of Set 11 | puntarenas
# Processing Record 23 of Set 11 | tamandare
# Processing Record 24 of Set 11 | xining
# Processing Record 25 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 11 | lata
# Processing Record 27 of Set 11 | toyooka
# Processing Record 28 of Set 11 | terrace
# Processing Record 29 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 11 | iramuco
# Processing Record 31 of Set 11 | vulcan
# Processing Record 32 of Set 11 | sarangani
# Processing Record 33 of Set 11 | buala
# Processing Record 34 of Set 11 | jalu
# Processing Record 35 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 11 | soltsy
# Processing Record 37 of Set 11 | qasigiannguit
# Processing Record 38 of Set 11 | monrovia
# Processing Record 39 of Set 11 | ust-maya
# Processing Record 40 of Set 11 | myitkyina
# Processing Record 41 of Set 11 | atar
# Processing Record 42 of Set 11 | mineros
# Processing Record 43 of Set 11 | oppdal
# Processing Record 44 of Set 11 | chapais
# Processing Record 45 of Set 11 | kurilsk
# Processing Record 46 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 47 of Set 11 | kizukuri
# Processing Record 48 of Set 11 | orange
# Processing Record 49 of Set 11 | rosarito
# Processing Record 50 of Set 11 | lensk
# Processing Record 1 of Set 12 | cedar city
# Processing Record 2 of Set 12 | presidencia roque saenz pena
# Processing Record 3 of Set 12 | ometepec
# Processing Record 4 of Set 12 | gazanjyk
# Processing Record 5 of Set 12 | senador jose porfirio
# Processing Record 6 of Set 12 | vila velha
# Processing Record 7 of Set 12 | litovko
# Processing Record 8 of Set 12 | grindavik
# Processing Record 9 of Set 12 | wakema
# Processing Record 10 of Set 12 | george
# Processing Record 11 of Set 12 | benemerito de las americas
# Processing Record 12 of Set 12 | sosnovo-ozerskoye
# Processing Record 13 of Set 12 | boden
# Processing Record 14 of Set 12 | cairns
# Processing Record 15 of Set 12 | azangaro
# Processing Record 16 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 17 of Set 12 | kaka
# Processing Record 18 of Set 12 | kandrian
# Processing Record 19 of Set 12 | nuevo progreso
# Processing Record 20 of Set 12 | glenwood springs
# Processing Record 21 of Set 12 | dalvik
# Processing Record 22 of Set 12 | pitkyaranta
# Processing Record 23 of Set 12 | manturovo
# Processing Record 24 of Set 12 | bettendorf
# Processing Record 25 of Set 12 | corinto
# Processing Record 26 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 12 | sisimiut
# Processing Record 28 of Set 12 | xichang
# Processing Record 29 of Set 12 | samarai
# Processing Record 30 of Set 12 | salekhard
# Processing Record 31 of Set 12 | waipawa
# Processing Record 32 of Set 12 | san marcos
# Processing Record 33 of Set 12 | kuntaur
# Processing Record 34 of Set 12 | natal
# Processing Record 35 of Set 12 | san lorenzo
# Processing Record 36 of Set 12 | kuusamo
# Processing Record 37 of Set 12 | bandarbeyla
# Processing Record 38 of Set 12 | kolobrzeg
# Processing Record 39 of Set 12 | na wa
# Processing Record 40 of Set 12 | pemangkat
# Processing Record 41 of Set 12 | kadambur
# Processing Record 42 of Set 12 | sitka
# Processing Record 43 of Set 12 | sao felix do xingu
# Processing Record 44 of Set 12 | huilong
# Processing Record 45 of Set 12 | umm lajj
# Processing Record 46 of Set 12 | puerto carreno
# Processing Record 47 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 12 | kawalu
# Processing Record 49 of Set 12 | tabou
# Processing Record 50 of Set 12 | scottsbluff
# Processing Record 1 of Set 13 | moose factory
# Processing Record 2 of Set 13 | port hardy
# Processing Record 3 of Set 13 | hastings
# Processing Record 4 of Set 13 | tuatapere
# Processing Record 5 of Set 13 | dalbandin
# Processing Record 6 of Set 13 | veydelevka
# Processing Record 7 of Set 13 | valle de allende
# Processing Record 8 of Set 13 | kaele
# Processing Record 9 of Set 13 | tairua
# Processing Record 10 of Set 13 | kaupanger
# Processing Record 11 of Set 13 | hokitika
# Processing Record 12 of Set 13 | anadyr
# Processing Record 13 of Set 13 | emerald
# Processing Record 14 of Set 13 | altamira
# Processing Record 15 of Set 13 | dawson creek
# Processing Record 16 of Set 13 | shimoda
# Processing Record 17 of Set 13 | takoradi
# Processing Record 18 of Set 13 | sept-iles
# Processing Record 19 of Set 13 | helena
# Processing Record 20 of Set 13 | bilma
# Processing Record 21 of Set 13 | kokoda
# Processing Record 22 of Set 13 | weligama
# Processing Record 23 of Set 13 | dale
# Processing Record 24 of Set 13 | cocorit
# Processing Record 25 of Set 13 | santa vitoria do palmar
# Processing Record 26 of Set 13 | tolaga bay
# Processing Record 27 of Set 13 | phetchabun
# Processing Record 28 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 13 | is
# City not found. Skipping...
# Processing Record 31 of Set 13 | matehuala
# Processing Record 32 of Set 13 | cravo norte
# Processing Record 33 of Set 13 | mana
# Processing Record 34 of Set 13 | ingham
# Processing Record 35 of Set 13 | aksu
# Processing Record 36 of Set 13 | mpwapwa
# Processing Record 37 of Set 13 | ukiah
# Processing Record 38 of Set 13 | esil
# Processing Record 39 of Set 13 | esmeraldas
# Processing Record 40 of Set 13 | wanning
# Processing Record 41 of Set 13 | gao
# Processing Record 42 of Set 13 | baoding
# Processing Record 43 of Set 13 | robstown
# Processing Record 44 of Set 13 | kukmor
# Processing Record 45 of Set 13 | chirongui
# Processing Record 46 of Set 13 | otane
# Processing Record 47 of Set 13 | diofior
# Processing Record 48 of Set 13 | huarmey
# Processing Record 49 of Set 13 | manali
# Processing Record 50 of Set 13 | neiafu
# Processing Record 1 of Set 14 | bajos de haina
# Processing Record 2 of Set 14 | gobabis
# Processing Record 3 of Set 14 | caucaia
# Processing Record 4 of Set 14 | roald
# Processing Record 5 of Set 14 | bundaberg
# Processing Record 6 of Set 14 | loiza
# Processing Record 7 of Set 14 | evensk
# Processing Record 8 of Set 14 | jinxiang
# Processing Record 9 of Set 14 | manono
# Processing Record 10 of Set 14 | yebaishou
# Processing Record 11 of Set 14 | pasni
# Processing Record 12 of Set 14 | kalmunai
# Processing Record 13 of Set 14 | lundazi
# Processing Record 14 of Set 14 | kralendijk
# Processing Record 15 of Set 14 | oum hadjer
# Processing Record 16 of Set 14 | channel-port aux basques
# Processing Record 17 of Set 14 | russell
# Processing Record 18 of Set 14 | isla vista
# Processing Record 19 of Set 14 | ketchikan
# Processing Record 20 of Set 14 | arlit
# Processing Record 21 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 14 | villaviciosa
# Processing Record 23 of Set 14 | waitati
# Processing Record 24 of Set 14 | pirovskoye
# Processing Record 25 of Set 14 | pafos
# Processing Record 26 of Set 14 | lang suan
# Processing Record 27 of Set 14 | elko
# Processing Record 28 of Set 14 | sobolevo
# Processing Record 29 of Set 14 | fuerte olimpo
# Processing Record 30 of Set 14 | kodinsk
# Processing Record 31 of Set 14 | tjome
# Processing Record 32 of Set 14 | lagos
# Processing Record 33 of Set 14 | kadom
# Processing Record 34 of Set 14 | yamada
# Processing Record 35 of Set 14 | wajima
# Processing Record 36 of Set 14 | namibe
# Processing Record 37 of Set 14 | totoral
# Processing Record 38 of Set 14 | auki
# Processing Record 39 of Set 14 | yanam
# Processing Record 40 of Set 14 | pulivendla
# Processing Record 41 of Set 14 | australind
# Processing Record 42 of Set 14 | ulladulla
# Processing Record 43 of Set 14 | tongren
# Processing Record 44 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 14 | laguna
# Processing Record 46 of Set 14 | dabola
# Processing Record 47 of Set 14 | tougan
# Processing Record 48 of Set 14 | marathon
# Processing Record 49 of Set 14 | morondava
# Processing Record 50 of Set 14 | ruteng
# Processing Record 1 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 15 | camacha
# Processing Record 3 of Set 15 | codo
# Processing Record 4 of Set 15 | kimbe
# Processing Record 5 of Set 15 | visalia
# Processing Record 6 of Set 15 | byron bay
# Processing Record 7 of Set 15 | aykhal
# Processing Record 8 of Set 15 | belle fourche
# Processing Record 9 of Set 15 | plainview
# Processing Record 10 of Set 15 | road town
# Processing Record 11 of Set 15 | ahipara
# Processing Record 12 of Set 15 | juba
# Processing Record 13 of Set 15 | tateyama
# Processing Record 14 of Set 15 | drayton valley
# Processing Record 15 of Set 15 | alghero
# Processing Record 16 of Set 15 | mosquera
# Processing Record 17 of Set 15 | sitamarhi
# Processing Record 18 of Set 15 | kaseda
# Processing Record 19 of Set 15 | san policarpo
# Processing Record 20 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 15 | gordeyevka
# Processing Record 22 of Set 15 | inuvik
# Processing Record 23 of Set 15 | virginia beach
# Processing Record 24 of Set 15 | batemans bay
# Processing Record 25 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 15 | port hedland
# Processing Record 27 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 28 of Set 15 | port-cartier
# Processing Record 29 of Set 15 | kathu
# Processing Record 30 of Set 15 | ternate
# Processing Record 31 of Set 15 | tangjiazhuang
# Processing Record 32 of Set 15 | alanya
# Processing Record 33 of Set 15 | ziway
# Processing Record 34 of Set 15 | ikom
# Processing Record 35 of Set 15 | joensuu
# Processing Record 36 of Set 15 | lander
# Processing Record 37 of Set 15 | cizre
# Processing Record 38 of Set 15 | boyolangu
# Processing Record 39 of Set 15 | itarema
# Processing Record 40 of Set 15 | odweyne
# Processing Record 41 of Set 15 | morti
# City not found. Skipping...
# Processing Record 42 of Set 15 | katsuura
# Processing Record 43 of Set 15 | pedasi
# Processing Record 44 of Set 15 | mundo nuevo
# Processing Record 45 of Set 15 | shirokiy
# Processing Record 46 of Set 15 | mahanje
# Processing Record 47 of Set 15 | namtsy
# Processing Record 48 of Set 15 | hay river
# Processing Record 49 of Set 15 | paso de patria
# Processing Record 50 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 16 | homestead
# Processing Record 2 of Set 16 | sundargarh
# Processing Record 3 of Set 16 | bosobolo
# Processing Record 4 of Set 16 | sinor
# Processing Record 5 of Set 16 | melito di porto salvo
# Processing Record 6 of Set 16 | anchorage
# Processing Record 7 of Set 16 | flin flon
# Processing Record 8 of Set 16 | skagen
# Processing Record 9 of Set 16 | katherine
# Processing Record 10 of Set 16 | dudinka
# Processing Record 11 of Set 16 | tiznit
# Processing Record 12 of Set 16 | winnemucca
# Processing Record 13 of Set 16 | ostrovnoy
# Processing Record 14 of Set 16 | kamloops
# Processing Record 15 of Set 16 | saurimo
# Processing Record 16 of Set 16 | mogadishu
# Processing Record 17 of Set 16 | kysyl-syr
# Processing Record 18 of Set 16 | skelleftea
# Processing Record 19 of Set 16 | jiamusi
# Processing Record 20 of Set 16 | saint-joseph
# Processing Record 21 of Set 16 | penha
# Processing Record 22 of Set 16 | ugoofaaru
# Processing Record 23 of Set 16 | yuanping
# Processing Record 24 of Set 16 | salinopolis
# Processing Record 25 of Set 16 | boguchany
# Processing Record 26 of Set 16 | balaipungut
# Processing Record 27 of Set 16 | kailua
# Processing Record 28 of Set 16 | wagar
# Processing Record 29 of Set 16 | sao cristovao
# Processing Record 30 of Set 16 | kiunga
# Processing Record 31 of Set 16 | awjilah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Cape Town -33.9258   18.4232     60.28        88          75
# 1     Puerto Ayora  -0.7393  -90.3518     72.55        96          49
# 2             Poso  -1.3959  120.7524     83.34        70          79
# 3          Ushuaia -54.8000  -68.3000     33.46        80          20
# 4  Lazaro Cardenas  17.9583 -102.2000     78.93        77          45
# 5      Provideniya  64.3833 -173.3000     46.51        76           0
# 6           Torbay  47.6666  -52.7314     53.58        93         100
# 7      Tuktoyaktuk  69.4541 -133.0374     28.40        74          20
# 8          Fortuna  40.5982 -124.1573     62.92        74           0
# 9             Vila  42.0304   -8.1588     44.71        81          91
#
#    Wind Speed Country                 Date      Current Description
# 0       10.36      ZA  2022-05-24 00:32:27            broken clouds
# 1        1.01      EC  2022-05-24 00:33:24         scattered clouds
# 2        2.80      ID  2022-05-24 00:36:18            broken clouds
# 3        8.05      AR  2022-05-24 00:32:39               few clouds
# 4       10.38      MX  2022-05-24 00:36:18         scattered clouds
# 5        4.47      RU  2022-05-24 00:36:18                clear sky
# 6       17.27      CA  2022-05-24 00:35:31  light intensity drizzle
# 7        5.75      CA  2022-05-24 00:35:42               few clouds
# 8       16.11      US  2022-05-24 00:35:52                clear sky
# 9        2.86      PT  2022-05-24 00:36:19          overcast clouds

# %%
new_col_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_col_order]

city_data_df.head(10)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0        Cape Town      ZA  2022-05-24 00:32:27 -33.9258   18.4232     60.28
# 1     Puerto Ayora      EC  2022-05-24 00:33:24  -0.7393  -90.3518     72.55
# 2             Poso      ID  2022-05-24 00:36:18  -1.3959  120.7524     83.34
# 3          Ushuaia      AR  2022-05-24 00:32:39 -54.8000  -68.3000     33.46
# 4  Lazaro Cardenas      MX  2022-05-24 00:36:18  17.9583 -102.2000     78.93
# 5      Provideniya      RU  2022-05-24 00:36:18  64.3833 -173.3000     46.51
# 6           Torbay      CA  2022-05-24 00:35:31  47.6666  -52.7314     53.58
# 7      Tuktoyaktuk      CA  2022-05-24 00:35:42  69.4541 -133.0374     28.40
# 8          Fortuna      US  2022-05-24 00:35:52  40.5982 -124.1573     62.92
# 9             Vila      PT  2022-05-24 00:36:19  42.0304   -8.1588     44.71
#
#    Humidity  Cloudiness  Wind Speed      Current Description
# 0        88          75       10.36            broken clouds
# 1        96          49        1.01         scattered clouds
# 2        70          79        2.80            broken clouds
# 3        80          20        8.05               few clouds
# 4        77          45       10.38         scattered clouds
# 5        76           0        4.47                clear sky
# 6        93         100       17.27  light intensity drizzle
# 7        74          20        5.75               few clouds
# 8        74           0       16.11                clear sky
# 9        81          91        2.86          overcast clouds

# %%
# Create the output file (CSV) in the weather_data folder.
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
